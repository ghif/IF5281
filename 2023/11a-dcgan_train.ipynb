# %% [markdown]
# # Deep Convolutional Generative Adversarial Networks (DCGAN)

# %% [markdown]
# The following DC-GAN training code is written to be executed via Google Colab using GDrive as the file storage.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Insert the directory
import sys
sys.path.insert(0, '/content/drive/My Drive/Colab Notebooks')

# %%
# Load all relevant modules
import os
import time as timer

import torch
from torch import nn
from torch import optim
from torch.utils.data import DataLoader

import numpy as np
from IPython import display
from skimage.util import random_noise

from torchvision import datasets
import torchvision.transforms as T
import torchvision.utils as vutils

import res.viz_utils as vu
from res.plot_lib import set_default

set_default()

# %%
GDRIVE_DIR = "/content/drive/My Drive/Colab Notebooks/"

# Define default constants

# Data related constants
# DATASET = 'cifar10'
# DATASET = 'cifar100'
# DATASET = 'celebA'
DATASET = 'svhn'

DATA_DIR = os.path.join(GDRIVE_DIR, "data")
BATCH_SIZE = 64
NUM_EPOCH = 25
IMAGE_SIZE = 64
NUM_WORKERS = 2
DAY = '4may'

# Model related constants
MODEL_DIR = os.path.join(GDRIVE_DIR, "models")
SAMPLE_DIR = os.path.join(MODEL_DIR, f"gen_samples_{DATASET}_{DAY}")

# create SAMPLE_DIR if not exists
if not os.path.exists(SAMPLE_DIR):
    os.makedirs(SAMPLE_DIR)
    print(f'The new directory {SAMPLE_DIR} has been created')

NC = 3 # num channels
NZ = 100 # num latent variables
NGF = 64 # num generator filters
NDF = 64 # num discriminator filters
NGPU = 1 # num GPUs
LR = 2e-4 # learning rate
BETA1 = 0.5 # beta1 for Adam optimizer

# pretrained_gen_model_path = os.path.join(MODEL_DIR, f"dcgan_gen_{DATASET}_z100_ep25.pth")
# pretrained_dis_model_path = os.path.join(MODEL_DIR, f"dcgan_dis_{DATASET}_z100_ep25.pth")
pretrained_gen_model_path = None
pretrained_dis_model_path = None

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# !nvidia-smi
# Out:
# Thu May  4 05:58:49 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    12W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Load Training and Test Dataset

# %%
# Transform to (-1, 1) 
img_transform = T.Compose([
    T.Resize(IMAGE_SIZE),
    T.CenterCrop(IMAGE_SIZE),
    T.ToTensor(),
    T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

if DATASET == 'cifar10':
  dataset_func = datasets.CIFAR10
elif DATASET == 'cifar100':
  dataset_func = datasets.CIFAR100
elif DATASET == 'celebA':
  dataset_func = datasets.CelebA
elif DATASET == 'svhn':
  dataset_func = datasets.SVHN

if DATASET in ['cifar10', 'cifar100']:
  # Load train
  train_data = dataset_func(
      root=DATA_DIR,
      train=True,
      download=True,
      transform=img_transform,
  )

  # Load test
  test_data = dataset_func(
      root=DATA_DIR,
      train=False,
      download=True,
      transform=img_transform,
  )
else:
  # Load train
  train_data = dataset_func(
      root=DATA_DIR,
      split='train',
      download=True,
      transform=img_transform,
  )

  # Load test
  test_data = dataset_func(
      root=DATA_DIR,
      split='test',
      download=True,
      transform=img_transform,
  )
# Out:
# Using downloaded and verified file: /content/drive/My Drive/Colab Notebooks/data/train_32x32.mat
# Using downloaded and verified file: /content/drive/My Drive/Colab Notebooks/data/test_32x32.mat

# %%
# Create data loader
train_loader = DataLoader(
    train_data,
    shuffle=True,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
)

test_loader = DataLoader(
    test_data,
    shuffle=False,
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
)

# %% [markdown]
# ### Define Generator and Discriminator Networks

# %%
# Define model architecture and loss function

# custom weights initialization called on netG and netD
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("BatchNorm") != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.zeros_(m.bias.data)

class Generator(nn.Module):
    def __init__(self, nz, ngf, nc, ngpu=0):
        super().__init__()

        self.ngpu = ngpu

        self.network = nn.Sequential(
            # Input is Z, going into a convolution
            nn.ConvTranspose2d(nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(inplace=True),

            # state size: (ngf * 8) x 4 x 4
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(inplace=True),

            # state size: (ngf * 4) x 8 x 8
            nn.ConvTranspose2d(ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(inplace=True),

            # state size: (ngf * 2) x 16 x 16
            nn.ConvTranspose2d(ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(inplace=True),

            # state size: (ngf) x 32 x 32
            nn.ConvTranspose2d(ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
            # state size: (nc) x 64 x 64
        )
    
    def forward(self, input):
        if input.is_cuda and self.ngpu > 1:
            output = nn.parallel.data_parallel(self.network, input, range(self.ngpu))
        else:
            output = self.network(input)
        return output

# %%
netG = Generator(NZ, NGF, NC, ngpu=NGPU).to(DEVICE)
netG.apply(weights_init)

if pretrained_gen_model_path is not None:
  netG.load_state_dict(torch.load(pretrained_gen_model_path))
print(netG)
# Out:
# Generator(
#   (network): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )

# %%
class Discriminator(nn.Module):
    def __init__(self, nz, ndf, nc, ngpu=0):
        super().__init__()
        self.ngpu = ngpu
        self.network = nn.Sequential(
            # input is (nc) x 64 x 64
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),

            # state size: (ndf) x 32 x 32
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),

            # state size: (ndf * 2) x 16 x 16
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),

            # state size: (ndf * 4) x 8 x 8
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),

            # state size: (ndf * 8) x 4 x 4
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input):
        if input.is_cuda and self.ngpu > 1:
            output = nn.parallel.data_parallel(self.network, input, range(self.ngpu))
        else:
            output = self.network(input)
        return output.view(-1, 1).squeeze(1)

# %%
netD = Discriminator(NZ, NDF, NC, ngpu=NGPU).to(DEVICE)
netD.apply(weights_init)
if pretrained_dis_model_path is not None:
  netD.load_state_dict(torch.load(pretrained_dis_model_path))
print(netD)
# Out:
# Discriminator(
#   (network): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )

# %%
# Define loss function and optimizers
criterion = nn.BCELoss()

fixed_noise = torch.randn(64, NZ, 1, 1, device=DEVICE)
real_label = 1
fake_label = 0

optimizerD = optim.Adam(netD.parameters(), lr=LR, betas=(BETA1, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=LR, betas=(BETA1, 0.999))

# %% [markdown]
# ### Train and Store the Models

# %%
gname = "dcgan_gen" 
gen_path = os.path.join(MODEL_DIR, f"{gname}_{DATASET}_z{NZ}_ep{NUM_EPOCH}_{DAY}.pth")

dname = "dcgan_dis" 
dis_path = os.path.join(MODEL_DIR, f"{dname}_{DATASET}_z{NZ}_ep{NUM_EPOCH}_{DAY}.pth")


for epoch in range(NUM_EPOCH):
    
    for batch_idx, (X, _) in enumerate(train_loader):
        start_t = timer.time()
        ############################
        #  Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################

        # Train with real image
        netD.zero_grad()
        real_cpu = X.to(DEVICE)
        batch_size = real_cpu.size(0)
        label = torch.full(
            (batch_size,), real_label,
            dtype=real_cpu.dtype, 
            device=DEVICE
        )

        output = netD(real_cpu)
        errD_real = criterion(output, label)
        errD_real.backward()
        D_x = output.mean().item()

        # Train with fake image
        noise = torch.randn(batch_size, NZ, 1, 1, device=DEVICE)
        fake = netG(noise)
        label.fill_(fake_label)
        output = netD(fake.detach())
        errD_fake = criterion(output, label)
        errD_fake.backward()
        D_G_z1 = output.mean().item()

        errD = errD_real + errD_fake
        optimizerD.step()

        ############################
        # Update G network: minimize log(D(x)) + log(1 - D(G(z)))
        ###########################
        netG.zero_grad()
        label.fill_(real_label) # fake labels are real for generator cost
        output = netD(fake)
        errG = criterion(output, label)
        errG.backward()
        D_G_z2 = output.mean().item()
        optimizerG.step()
        elapsed_t = timer.time() - start_t

        if batch_idx % 100 == 0:
            print(f'[{epoch+1}/{NUM_EPOCH}] [{batch_idx} / {len(train_loader)}] Loss_D: {errD.item():.4f} Loss_G: {errG.item():.4f} D(x): {D_x:.4f} D(G(z)): {D_G_z1:.4f} / {D_G_z2:.4f} Elapsed: {elapsed_t:.2f} secs')
            vutils.save_image(real_cpu, f'{SAMPLE_DIR}/real_samples.png', normalize=True)
            fake = netG(fixed_noise)
            vutils.save_image(fake.detach(), f'{SAMPLE_DIR}/fake_samples_epoch-{epoch+1}_batch-{batch_idx}.png', normalize=True)

            # Checkpointing
            torch.save(netD.state_dict(), dis_path)
            print(f" --- Discriminator model stored in {dis_path} ---")

            torch.save(netG.state_dict(), gen_path)
            print(f" --- Generator model stored in {gen_path} ---")        
    # end for batch
# end for epoch
# Out:
# [1/25] [0 / 1145] Loss_D: 1.8308 Loss_G: 6.4696 D(x): 0.5902 D(G(z)): 0.6342 / 0.0022 Elapsed: 2.46 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [100 / 1145] Loss_D: 0.0031 Loss_G: 40.0834 D(x): 0.9970 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [200 / 1145] Loss_D: 0.0006 Loss_G: 39.4786 D(x): 0.9994 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [300 / 1145] Loss_D: 0.0001 Loss_G: 39.2650 D(x): 0.9999 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [400 / 1145] Loss_D: 0.0001 Loss_G: 38.9588 D(x): 0.9999 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [500 / 1145] Loss_D: 0.0000 Loss_G: 38.8337 D(x): 1.0000 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [600 / 1145] Loss_D: 0.0001 Loss_G: 38.0757 D(x): 0.9999 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [700 / 1145] Loss_D: 0.0000 Loss_G: 36.7243 D(x): 1.0000 D(G(z)): 0.0000 / 0.0000 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [800 / 1145] Loss_D: 0.4524 Loss_G: 9.0421 D(x): 0.9353 D(G(z)): 0.2768 / 0.0006 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [900 / 1145] Loss_D: 0.1422 Loss_G: 4.2890 D(x): 0.9260 D(G(z)): 0.0591 / 0.0164 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [1000 / 1145] Loss_D: 1.1491 Loss_G: 3.8833 D(x): 0.5705 D(G(z)): 0.0273 / 0.0600 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [1/25] [1100 / 1145] Loss_D: 0.4405 Loss_G: 4.7725 D(x): 0.8999 D(G(z)): 0.2369 / 0.0208 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [0 / 1145] Loss_D: 0.2099 Loss_G: 4.3643 D(x): 0.8657 D(G(z)): 0.0407 / 0.0194 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [100 / 1145] Loss_D: 0.6629 Loss_G: 5.3318 D(x): 0.9218 D(G(z)): 0.3696 / 0.0123 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [200 / 1145] Loss_D: 0.7808 Loss_G: 1.5078 D(x): 0.7510 D(G(z)): 0.3176 / 0.2860 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [300 / 1145] Loss_D: 0.5702 Loss_G: 2.9330 D(x): 0.8240 D(G(z)): 0.2699 / 0.0886 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [400 / 1145] Loss_D: 0.8411 Loss_G: 5.8131 D(x): 0.8329 D(G(z)): 0.3960 / 0.0068 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [500 / 1145] Loss_D: 1.3740 Loss_G: 1.5145 D(x): 0.4011 D(G(z)): 0.1947 / 0.2564 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [600 / 1145] Loss_D: 0.5905 Loss_G: 2.8172 D(x): 0.6782 D(G(z)): 0.1216 / 0.0846 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [700 / 1145] Loss_D: 0.4578 Loss_G: 2.5834 D(x): 0.8050 D(G(z)): 0.1811 / 0.0965 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [800 / 1145] Loss_D: 1.2040 Loss_G: 1.0250 D(x): 0.3773 D(G(z)): 0.0488 / 0.4279 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [900 / 1145] Loss_D: 0.7187 Loss_G: 3.3743 D(x): 0.7853 D(G(z)): 0.3125 / 0.0575 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [1000 / 1145] Loss_D: 0.5743 Loss_G: 3.0425 D(x): 0.8294 D(G(z)): 0.2820 / 0.0624 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [2/25] [1100 / 1145] Loss_D: 0.5492 Loss_G: 2.8992 D(x): 0.8437 D(G(z)): 0.2816 / 0.0742 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [0 / 1145] Loss_D: 0.8100 Loss_G: 2.0691 D(x): 0.6339 D(G(z)): 0.1748 / 0.1837 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [100 / 1145] Loss_D: 0.5185 Loss_G: 2.2918 D(x): 0.7227 D(G(z)): 0.1406 / 0.1385 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [200 / 1145] Loss_D: 0.5994 Loss_G: 1.7871 D(x): 0.6311 D(G(z)): 0.0573 / 0.2473 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [300 / 1145] Loss_D: 0.9321 Loss_G: 0.5434 D(x): 0.4973 D(G(z)): 0.0675 / 0.6101 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [400 / 1145] Loss_D: 0.5896 Loss_G: 1.6359 D(x): 0.6236 D(G(z)): 0.0166 / 0.2648 Elapsed: 0.06 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [500 / 1145] Loss_D: 0.4344 Loss_G: 2.5785 D(x): 0.7650 D(G(z)): 0.1267 / 0.0937 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [600 / 1145] Loss_D: 0.5803 Loss_G: 2.9455 D(x): 0.6405 D(G(z)): 0.0321 / 0.0810 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [700 / 1145] Loss_D: 0.6161 Loss_G: 1.8146 D(x): 0.6991 D(G(z)): 0.1721 / 0.2081 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [800 / 1145] Loss_D: 0.8210 Loss_G: 2.6471 D(x): 0.5082 D(G(z)): 0.0135 / 0.1258 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [900 / 1145] Loss_D: 0.2682 Loss_G: 3.4015 D(x): 0.8418 D(G(z)): 0.0742 / 0.0493 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [1000 / 1145] Loss_D: 0.8687 Loss_G: 5.3441 D(x): 0.9611 D(G(z)): 0.5290 / 0.0100 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [3/25] [1100 / 1145] Loss_D: 0.9167 Loss_G: 4.8347 D(x): 0.9748 D(G(z)): 0.5400 / 0.0148 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [0 / 1145] Loss_D: 2.0455 Loss_G: 7.8284 D(x): 0.9742 D(G(z)): 0.7878 / 0.0009 Elapsed: 0.06 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [100 / 1145] Loss_D: 0.1846 Loss_G: 4.0105 D(x): 0.8679 D(G(z)): 0.0316 / 0.0265 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [200 / 1145] Loss_D: 0.7918 Loss_G: 1.8732 D(x): 0.6013 D(G(z)): 0.1487 / 0.2497 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [300 / 1145] Loss_D: 1.2431 Loss_G: 5.5230 D(x): 0.8917 D(G(z)): 0.6020 / 0.0107 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [400 / 1145] Loss_D: 0.8640 Loss_G: 0.9241 D(x): 0.4787 D(G(z)): 0.0429 / 0.4608 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [500 / 1145] Loss_D: 0.3056 Loss_G: 4.7899 D(x): 0.9568 D(G(z)): 0.2179 / 0.0123 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [600 / 1145] Loss_D: 0.2727 Loss_G: 2.7439 D(x): 0.8893 D(G(z)): 0.1295 / 0.0903 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [700 / 1145] Loss_D: 0.2976 Loss_G: 3.5248 D(x): 0.9739 D(G(z)): 0.2206 / 0.0413 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [800 / 1145] Loss_D: 1.2766 Loss_G: 0.9753 D(x): 0.3581 D(G(z)): 0.0079 / 0.4880 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [900 / 1145] Loss_D: 1.4302 Loss_G: 1.7663 D(x): 0.3684 D(G(z)): 0.1243 / 0.2404 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [1000 / 1145] Loss_D: 0.3041 Loss_G: 5.2544 D(x): 0.7580 D(G(z)): 0.0025 / 0.0093 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [4/25] [1100 / 1145] Loss_D: 0.1269 Loss_G: 3.3957 D(x): 0.9755 D(G(z)): 0.0914 / 0.0480 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [0 / 1145] Loss_D: 0.6722 Loss_G: 3.4904 D(x): 0.9220 D(G(z)): 0.4047 / 0.0446 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [100 / 1145] Loss_D: 0.6742 Loss_G: 5.7751 D(x): 0.9846 D(G(z)): 0.4448 / 0.0051 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [200 / 1145] Loss_D: 0.0521 Loss_G: 4.3650 D(x): 0.9773 D(G(z)): 0.0283 / 0.0179 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [300 / 1145] Loss_D: 0.8672 Loss_G: 3.4667 D(x): 0.8851 D(G(z)): 0.4503 / 0.0509 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [400 / 1145] Loss_D: 0.3975 Loss_G: 3.8108 D(x): 0.8349 D(G(z)): 0.1638 / 0.0342 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [500 / 1145] Loss_D: 0.2840 Loss_G: 3.5112 D(x): 0.8764 D(G(z)): 0.1262 / 0.0487 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [600 / 1145] Loss_D: 0.1845 Loss_G: 3.0411 D(x): 0.9360 D(G(z)): 0.1025 / 0.0688 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [700 / 1145] Loss_D: 0.0507 Loss_G: 4.1731 D(x): 0.9723 D(G(z)): 0.0218 / 0.0232 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [800 / 1145] Loss_D: 0.6418 Loss_G: 3.0955 D(x): 0.8709 D(G(z)): 0.3494 / 0.0639 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [900 / 1145] Loss_D: 1.1144 Loss_G: 1.6685 D(x): 0.6287 D(G(z)): 0.3967 / 0.2454 Elapsed: 0.09 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [1000 / 1145] Loss_D: 0.0742 Loss_G: 4.5788 D(x): 0.9435 D(G(z)): 0.0139 / 0.0141 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [5/25] [1100 / 1145] Loss_D: 0.6022 Loss_G: 2.9838 D(x): 0.6445 D(G(z)): 0.0872 / 0.0761 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [0 / 1145] Loss_D: 1.6933 Loss_G: 3.1909 D(x): 0.9357 D(G(z)): 0.7380 / 0.0555 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [100 / 1145] Loss_D: 0.4041 Loss_G: 5.5254 D(x): 0.9818 D(G(z)): 0.2953 / 0.0059 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [200 / 1145] Loss_D: 0.0959 Loss_G: 5.5701 D(x): 0.9158 D(G(z)): 0.0052 / 0.0075 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [300 / 1145] Loss_D: 0.1270 Loss_G: 3.6168 D(x): 0.8952 D(G(z)): 0.0096 / 0.0414 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [400 / 1145] Loss_D: 0.0686 Loss_G: 8.4571 D(x): 0.9361 D(G(z)): 0.0003 / 0.0004 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [500 / 1145] Loss_D: 0.0980 Loss_G: 4.0607 D(x): 0.9565 D(G(z)): 0.0498 / 0.0251 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [600 / 1145] Loss_D: 0.0402 Loss_G: 4.7410 D(x): 0.9941 D(G(z)): 0.0321 / 0.0137 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [700 / 1145] Loss_D: 0.0701 Loss_G: 4.3469 D(x): 0.9560 D(G(z)): 0.0233 / 0.0193 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [800 / 1145] Loss_D: 0.0579 Loss_G: 5.0806 D(x): 0.9921 D(G(z)): 0.0458 / 0.0096 Elapsed: 0.10 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [900 / 1145] Loss_D: 0.1887 Loss_G: 3.0949 D(x): 0.9633 D(G(z)): 0.1283 / 0.0868 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [1000 / 1145] Loss_D: 0.0985 Loss_G: 3.6820 D(x): 0.9384 D(G(z)): 0.0306 / 0.0425 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [6/25] [1100 / 1145] Loss_D: 0.1157 Loss_G: 3.8965 D(x): 0.9722 D(G(z)): 0.0795 / 0.0366 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [0 / 1145] Loss_D: 0.0633 Loss_G: 4.5045 D(x): 0.9574 D(G(z)): 0.0189 / 0.0165 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [100 / 1145] Loss_D: 0.0635 Loss_G: 3.7020 D(x): 0.9843 D(G(z)): 0.0461 / 0.0329 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [200 / 1145] Loss_D: 0.0275 Loss_G: 9.7775 D(x): 0.9732 D(G(z)): 0.0001 / 0.0001 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [300 / 1145] Loss_D: 3.5150 Loss_G: 1.7201 D(x): 0.0903 D(G(z)): 0.0035 / 0.2429 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [400 / 1145] Loss_D: 1.7636 Loss_G: 2.5551 D(x): 0.2263 D(G(z)): 0.0132 / 0.1456 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [500 / 1145] Loss_D: 0.9884 Loss_G: 2.4537 D(x): 0.7468 D(G(z)): 0.4534 / 0.1127 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [600 / 1145] Loss_D: 1.0411 Loss_G: 3.8162 D(x): 0.9135 D(G(z)): 0.5473 / 0.0291 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [700 / 1145] Loss_D: 0.1296 Loss_G: 3.4021 D(x): 0.9003 D(G(z)): 0.0179 / 0.0543 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [800 / 1145] Loss_D: 0.0371 Loss_G: 7.9683 D(x): 0.9702 D(G(z)): 0.0003 / 0.0006 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [900 / 1145] Loss_D: 0.0441 Loss_G: 6.6503 D(x): 0.9606 D(G(z)): 0.0032 / 0.0026 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [1000 / 1145] Loss_D: 0.1694 Loss_G: 6.6921 D(x): 0.9802 D(G(z)): 0.1247 / 0.0021 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [7/25] [1100 / 1145] Loss_D: 0.7400 Loss_G: 2.5276 D(x): 0.7014 D(G(z)): 0.2401 / 0.1307 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [0 / 1145] Loss_D: 0.6851 Loss_G: 1.8677 D(x): 0.7511 D(G(z)): 0.2614 / 0.2052 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [100 / 1145] Loss_D: 0.7874 Loss_G: 1.2449 D(x): 0.6361 D(G(z)): 0.2347 / 0.3454 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [200 / 1145] Loss_D: 0.5274 Loss_G: 3.7655 D(x): 0.8962 D(G(z)): 0.2985 / 0.0346 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [300 / 1145] Loss_D: 0.4850 Loss_G: 4.0528 D(x): 0.9266 D(G(z)): 0.3019 / 0.0248 Elapsed: 0.06 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [400 / 1145] Loss_D: 0.1302 Loss_G: 4.1424 D(x): 0.9086 D(G(z)): 0.0302 / 0.0233 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [500 / 1145] Loss_D: 0.0876 Loss_G: 7.0880 D(x): 0.9191 D(G(z)): 0.0012 / 0.0014 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [600 / 1145] Loss_D: 0.0574 Loss_G: 4.4605 D(x): 0.9642 D(G(z)): 0.0193 / 0.0186 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [700 / 1145] Loss_D: 3.7198 Loss_G: 4.1665 D(x): 0.9925 D(G(z)): 0.9505 / 0.0325 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [800 / 1145] Loss_D: 0.0346 Loss_G: 5.0724 D(x): 0.9776 D(G(z)): 0.0116 / 0.0117 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [900 / 1145] Loss_D: 0.1059 Loss_G: 4.9591 D(x): 0.9742 D(G(z)): 0.0733 / 0.0123 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [1000 / 1145] Loss_D: 0.6387 Loss_G: 5.9989 D(x): 0.9858 D(G(z)): 0.4118 / 0.0066 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [8/25] [1100 / 1145] Loss_D: 0.1049 Loss_G: 4.6235 D(x): 0.9939 D(G(z)): 0.0913 / 0.0144 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [0 / 1145] Loss_D: 0.1967 Loss_G: 4.1071 D(x): 0.9256 D(G(z)): 0.0602 / 0.0271 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [100 / 1145] Loss_D: 1.9192 Loss_G: 1.2688 D(x): 0.2123 D(G(z)): 0.0209 / 0.3695 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [200 / 1145] Loss_D: 0.0633 Loss_G: 4.6345 D(x): 0.9916 D(G(z)): 0.0511 / 0.0150 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [300 / 1145] Loss_D: 1.2185 Loss_G: 4.7787 D(x): 0.9703 D(G(z)): 0.6296 / 0.0145 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [400 / 1145] Loss_D: 0.0441 Loss_G: 4.8374 D(x): 0.9963 D(G(z)): 0.0387 / 0.0142 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [500 / 1145] Loss_D: 0.0073 Loss_G: 6.2298 D(x): 0.9981 D(G(z)): 0.0054 / 0.0031 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [600 / 1145] Loss_D: 0.0123 Loss_G: 6.0863 D(x): 0.9981 D(G(z)): 0.0103 / 0.0029 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [700 / 1145] Loss_D: 0.1426 Loss_G: 5.1570 D(x): 0.9300 D(G(z)): 0.0557 / 0.0136 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [800 / 1145] Loss_D: 0.1164 Loss_G: 5.4465 D(x): 0.9011 D(G(z)): 0.0060 / 0.0156 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [900 / 1145] Loss_D: 0.5455 Loss_G: 4.0249 D(x): 0.9203 D(G(z)): 0.3264 / 0.0259 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [1000 / 1145] Loss_D: 0.0180 Loss_G: 5.6862 D(x): 0.9877 D(G(z)): 0.0055 / 0.0054 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [9/25] [1100 / 1145] Loss_D: 0.1479 Loss_G: 4.1915 D(x): 0.9814 D(G(z)): 0.1100 / 0.0241 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [10/25] [0 / 1145] Loss_D: 0.0232 Loss_G: 4.9288 D(x): 0.9921 D(G(z)): 0.0144 / 0.0151 Elapsed: 0.06 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [10/25] [100 / 1145] Loss_D: 0.1114 Loss_G: 4.0543 D(x): 0.9563 D(G(z)): 0.0593 / 0.0283 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [10/25] [200 / 1145] Loss_D: 0.1115 Loss_G: 4.3370 D(x): 0.9855 D(G(z)): 0.0863 / 0.0177 Elapsed: 0.07 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [10/25] [300 / 1145] Loss_D: 0.5014 Loss_G: 3.2556 D(x): 0.8966 D(G(z)): 0.2912 / 0.0545 Elapsed: 0.08 secs
#  --- Discriminator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_dis_svhn_z100_ep25_4may.pth ---
#  --- Generator model stored in /content/drive/My Drive/Colab Notebooks/models/dcgan_gen_svhn_z100_ep25_4may.pth ---
# [10/25] [400 / 1145] Loss_D: 0.2848 Loss_G: 3.3509 D(x): 0.8020 D(G(z)): 0.0432 / 0.0560 Elapsed: 0.07 secs
